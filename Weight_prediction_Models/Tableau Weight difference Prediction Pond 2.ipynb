# %%
import pandas as pd
# Out:
# /home/rupamay/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv("Combined_Pond2_val_set.csv",delimiter=',',low_memory=False)

# %%
df.head()
df.drop("Unnamed: 0", axis=1)
# Out:
#                   Datetime  Temperature  Turbidity  Dissolved Oxygen       PH  \
# 0      2021-07-31 21:07:00      24.8750        6.0            38.702  7.29424
# 1      2021-07-31 21:08:00      24.9375        6.0            38.694  7.29424
# 2      2021-07-31 21:09:00      24.9375        6.0            38.677  7.30332
# 3      2021-07-31 21:10:00      24.8750        6.0            38.652  7.29424
# 4      2021-07-31 21:11:00      24.9375        6.0            38.855  7.30332
# ...                    ...          ...        ...               ...      ...
# 15432  2021-08-11 14:19:00      23.7500       88.0             4.597  7.12174
# 15433  2021-08-11 14:20:00      23.8125       89.0             3.972  7.12174
# 15434  2021-08-11 14:21:00      23.8125       89.0             3.374  7.11266
# 15435  2021-08-11 14:22:00      23.8125       89.0             3.374  7.11266
# 15436  2021-08-11 14:23:00      23.8125       89.0            10.774  7.11266
#
# ...

# %%
df1=pd.read_csv("Weight-diff_predictions_from_gradient_boosting_today.csv",delimiter=',',low_memory=False)

# %%
df1.columns=["Weight_diff_Pred"]

# %%
df1.head()
# Out:
#    Weight_diff_Pred
# 0          0.017593
# 1          0.017593
# 2          0.017593
# 3          0.017593
# 4          0.017593

# %%
df['Weight_diff_Pred']=df1['Weight_diff_Pred']

# %%
df.head()
# Out:
#    Unnamed: 0             Datetime  Temperature  Turbidity  Dissolved Oxygen  \
# 0       61747  2021-07-31 21:07:00      24.8750        6.0            38.702
# 1       61748  2021-07-31 21:08:00      24.9375        6.0            38.694
# 2       61749  2021-07-31 21:09:00      24.9375        6.0            38.677
# 3       61750  2021-07-31 21:10:00      24.8750        6.0            38.652
# 4       61751  2021-07-31 21:11:00      24.9375        6.0            38.855
#
#         PH  Ammonia  Nitrate  Population  Fish_Length  Fish_Weight  \
# 0  7.29424  0.56720    719.0        50.0        17.75         46.5
# 1  7.29424  0.57584    717.0        50.0        17.75         46.5
# 2  7.30332  0.56935    719.0        50.0        17.75         46.5
# 3  7.29424  0.56720    720.0        50.0        17.75         46.5
# 4  7.30332  0.53795    720.0        50.0        17.75         46.5
#
#    Weight_diff  Weight_diff_Pred
# 0          0.0          0.017593
# ...

# %%
df.to_csv("Tableau.csv")
